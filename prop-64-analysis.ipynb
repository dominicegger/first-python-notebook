# %% [markdown]
# # My First Notebook
#
# Hello World

# %% [markdown]
# Reading in the list of propositions and committes from CSV

# %%
import pandas as pd

# %% [markdown]
# Reading list of propositions

# %%
props = pd.read_csv("http://www.firstpythonnotebook.org/_static/committees.csv")

# %%
props.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4  ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
#
#    ccdc_prop_id                                          prop_name  \
# 0            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4            71  PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                382                 1374469
# ...

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# ocd_prop_id               102 non-null object
# calaccess_prop_id         102 non-null int64
# ccdc_prop_id              102 non-null int64
# prop_name                 102 non-null object
# ccdc_committee_id         102 non-null int64
# calaccess_committee_id    102 non-null int64
# committee_name            102 non-null object
# committee_position        102 non-null object
# dtypes: int64(4), object(4)
# memory usage: 4.8+ KB

# %% [markdown]
# Read in the list of contributions to ballot measures

# %%
contribs = pd.read_csv("contributions.csv")

# %%
contribs.head()
# Out:
#    calaccess_committee_id                              committee_name  \
# 0                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 1                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 2                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 3                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 4                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
#
#    calaccess_filing_id date_received contributor_lastname  \
# 0              2083796    2016-09-18              BERGMAN
# 1              2083796    2016-09-18                KAHLE
# 2              2083796    2016-07-15             MCDEVITT
# 3              2083796    2016-08-10      WARREN-SAMARIPA
# 4              2083796    2016-07-26      WARREN-SAMARIPA
#
#   contributor_firstname contributor_city contributor_state contributor_zip  \
# 0              GRETCHEN    SPRING VALLEY                CA           91978
# ...

# %%
contribs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56379 entries, 0 to 56378
# Data columns (total 13 columns):
# calaccess_committee_id          56379 non-null int64
# committee_name                  56379 non-null object
# calaccess_filing_id             56379 non-null int64
# date_received                   56379 non-null object
# contributor_lastname            56375 non-null object
# contributor_firstname           53411 non-null object
# contributor_city                56369 non-null object
# contributor_state               56363 non-null object
# contributor_zip                 56366 non-null object
# contributor_employer            48572 non-null object
# contributor_occupation          53273 non-null object
# contributor_is_self_employed    56379 non-null bool
# amount                          56379 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 3.3+ MB

# %%
props.prop_name.value_counts().reset_index()
# Out:
#                                                 index  prop_name
# 0   PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...         13
# 1   PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...         12
# 2   PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...         11
# 3   PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...          9
# 4   PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...          8
# 5   PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...          7
# 6   PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...          7
# 7   PROPOSITION 059- SB 254 (CHAPTER 20, STATUTES ...          6
# 8   PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...          4
# 9   PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...          4
# 10  PROPOSITION 058 - SB 1174 (CHAPTER 753, STATUT...          4
# 11  PROPOSITION 063- FIREARMS. AMMUNITION SALES. I...          4
# 12  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...          4
# ...

# %%
contribs.contributor_firstname.value_counts().reset_index()
# Out:
#               index  contributor_firstname
# 0             DAVID                    670
# 1           MICHAEL                    610
# 2            ROBERT                    588
# 3              JOHN                    540
# 4             JAMES                    364
# 5           RICHARD                    343
# 6           WILLIAM                    332
# 7              MARK                    279
# 8              PAUL                    231
# 9             NANCY                    199
# 10            SUSAN                    198
# 11           DANIEL                    189
# 12           THOMAS                    189
# 13            PETER                    189
# 14        ELIZABETH                    184
# 15             ERIC                    181
# 16         JENNIFER                    172
# 17          CHARLES                    171
# 18           STEVEN                    168
# 19           GEORGE                    165
# 20           JOSEPH                    157
# ...

# %%
props.prop_name.value_counts()
# Out:
# PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.                           13
# PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTHCARE, TOBACCO USE PREVENTION, RESEARCH, AND LAW ENFORCEMENT. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.    12
# PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.                                                                                                   11
# PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.                                                                                                 9
# PROPOSITION 055 - TAX EXTENSION TO FUND EDUCATION AND HEALTHCARE. INITIATIVE CONSTITUTIONAL AMENDMENT.                                                          8
# PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON SINGLE-USE PLASTIC BAGS.                                                                                         7
# ...

# %%
prop63 = props[props.prop_name == "PROPOSITION 063- FIREARMS. AMMUNITION SALES. INTIATIVE STATUTE."]

# %%
prop63.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 70 to 73
# Data columns (total 8 columns):
# ocd_prop_id               4 non-null object
# calaccess_prop_id         4 non-null int64
# ccdc_prop_id              4 non-null int64
# prop_name                 4 non-null object
# ccdc_committee_id         4 non-null int64
# calaccess_committee_id    4 non-null int64
# committee_name            4 non-null object
# committee_position        4 non-null object
# dtypes: int64(4), object(4)
# memory usage: 224.0+ bytes

# %%
contribs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56379 entries, 0 to 56378
# Data columns (total 13 columns):
# calaccess_committee_id          56379 non-null int64
# committee_name                  56379 non-null object
# calaccess_filing_id             56379 non-null int64
# date_received                   56379 non-null object
# contributor_lastname            56375 non-null object
# contributor_firstname           53411 non-null object
# contributor_city                56369 non-null object
# contributor_state               56363 non-null object
# contributor_zip                 56366 non-null object
# contributor_employer            48572 non-null object
# contributor_occupation          53273 non-null object
# contributor_is_self_employed    56379 non-null bool
# amount                          56379 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 3.3+ MB

# %%
prop63.head()
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 70  ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 71  ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 72  ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 73  ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
#
#     ccdc_prop_id                                          prop_name  \
# 70            82  PROPOSITION 063- FIREARMS. AMMUNITION SALES. I...
# 71            82  PROPOSITION 063- FIREARMS. AMMUNITION SALES. I...
# 72            82  PROPOSITION 063- FIREARMS. AMMUNITION SALES. I...
# 73            82  PROPOSITION 063- FIREARMS. AMMUNITION SALES. I...
#
#     ccdc_committee_id  calaccess_committee_id  \
# 70                452                 1382067
# 71                453                 1380746
# 72                454                 1380675
# 73                455                 1387279
#
# ...

# %%
merged = pd.merge(prop63, contribs, on="calaccess_committee_id")

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11025 entries, 0 to 11024
# Data columns (total 20 columns):
# ocd_prop_id                     11025 non-null object
# calaccess_prop_id               11025 non-null int64
# ccdc_prop_id                    11025 non-null int64
# prop_name                       11025 non-null object
# ccdc_committee_id               11025 non-null int64
# calaccess_committee_id          11025 non-null int64
# committee_name_x                11025 non-null object
# committee_position              11025 non-null object
# committee_name_y                11025 non-null object
# calaccess_filing_id             11025 non-null int64
# date_received                   11025 non-null object
# contributor_lastname            11025 non-null object
# contributor_firstname           10913 non-null object
# contributor_city                11023 non-null object
# contributor_state               11020 non-null object
# ...

# %%
merged.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 1  ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 2  ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 3  ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 4  ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
#
#    ccdc_prop_id                                          prop_name  \
# 0            82  PROPOSITION 063- FIREARMS. AMMUNITION SALES. I...
# 1            82  PROPOSITION 063- FIREARMS. AMMUNITION SALES. I...
# 2            82  PROPOSITION 063- FIREARMS. AMMUNITION SALES. I...
# 3            82  PROPOSITION 063- FIREARMS. AMMUNITION SALES. I...
# 4            82  PROPOSITION 063- FIREARMS. AMMUNITION SALES. I...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                452                 1382067
# ...

# %%
merged.amount.sum()
# Out:
# 3491136.6800000002

# %%
merged.committee_position.value_counts()
# Out:
# OPPOSE     5568
# SUPPORT    5457
# Name: committee_position, dtype: int64

# %%
merged.committee_position
# Out:
# 0        OPPOSE
# 1        OPPOSE
# 2        OPPOSE
# 3        OPPOSE
# 4        OPPOSE
# 5        OPPOSE
# 6        OPPOSE
# 7        OPPOSE
# 8        OPPOSE
# 9        OPPOSE
# 10       OPPOSE
# 11       OPPOSE
# 12       OPPOSE
# 13       OPPOSE
# 14       OPPOSE
# 15       OPPOSE
# 16       OPPOSE
# 17       OPPOSE
# 18       OPPOSE
# 19       OPPOSE
# 20       OPPOSE
# 21       OPPOSE
# 22       OPPOSE
# 23       OPPOSE
# 24       OPPOSE
# 25       OPPOSE
# 26       OPPOSE
# 27       OPPOSE
# 28       OPPOSE
# 29       OPPOSE
#           ...
# 10995    OPPOSE
# 10996    OPPOSE
# 10997    OPPOSE
# 10998    OPPOSE
# 10999    OPPOSE
# 11000    OPPOSE
# 11001    OPPOSE
# 11002    OPPOSE
# 11003    OPPOSE
# 11004    OPPOSE
# 11005    OPPOSE
# 11006    OPPOSE
# 11007    OPPOSE
# 11008    OPPOSE
# 11009    OPPOSE
# 11010    OPPOSE
# 11011    OPPOSE
# 11012    OPPOSE
# 11013    OPPOSE
# 11014    OPPOSE
# 11015    OPPOSE
# 11016    OPPOSE
# 11017    OPPOSE
# 11018    OPPOSE
# ...

# %%
support = merged[merged.committee_position == "SUPPORT"]

# %%
support
# Out:
#                                             ocd_prop_id  calaccess_prop_id  \
# 5293   ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 5294   ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 5295   ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 5296   ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 5297   ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 5298   ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 5299   ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 5300   ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 5301   ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 5302   ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 5303   ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# ...

# %%
oppose = merged[merged.committee_position == "OPPOSE"]

# %%
oppose
# Out:
#                                             ocd_prop_id  calaccess_prop_id  \
# 0      ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 1      ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 2      ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 3      ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 4      ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 5      ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 6      ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 7      ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 8      ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 9      ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 10     ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# ...

# %%
oppose.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5568 entries, 0 to 11024
# Data columns (total 20 columns):
# ocd_prop_id                     5568 non-null object
# calaccess_prop_id               5568 non-null int64
# ccdc_prop_id                    5568 non-null int64
# prop_name                       5568 non-null object
# ccdc_committee_id               5568 non-null int64
# calaccess_committee_id          5568 non-null int64
# committee_name_x                5568 non-null object
# committee_position              5568 non-null object
# committee_name_y                5568 non-null object
# calaccess_filing_id             5568 non-null int64
# date_received                   5568 non-null object
# contributor_lastname            5568 non-null object
# contributor_firstname           5463 non-null object
# contributor_city                5566 non-null object
# contributor_state               5566 non-null object
# contributor_zip                 5566 non-null object
# ...

# %%
support.amount.sum()
# Out:
# 2829869.1000000001

# %%
oppose.amount.sum()
# Out:
# 661267.57999999996

# %%
support.amount.sum() / merged.amount.sum()
# Out:
# 0.81058673990386421

# %%
oppose.amount.sum() / merged.amount.sum()
# Out:
# 0.18941326009613577

# %%
merged.sort_values("amount", ascending=False)
# Out:
#                                             ocd_prop_id  calaccess_prop_id  \
# 7534   ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 5729   ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 5529   ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 5812   ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 5813   ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 5582   ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 7372   ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 5293   ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 8005   ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 5456   ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 5864   ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# ...

# %%
oppose.sort_values("amount", ascending=False).head(10)
# Out:
#                                            ocd_prop_id  calaccess_prop_id  \
# 1594  ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 16    ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 5     ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 620   ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 2026  ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 2165  ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 0     ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 1288  ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 4     ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 74    ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
#
#       ccdc_prop_id                                          prop_name  \
# 1594            82  PROPOSITION 063- FIREARMS. AMMUNITION SALES. I...
# ...

# %%
merged.sort_values("amount", ascending=False)
# Out:
#                                             ocd_prop_id  calaccess_prop_id  \
# 7534   ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 5729   ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 5529   ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 5812   ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 5813   ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 5582   ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 7372   ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 5293   ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 8005   ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 5456   ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 5864   ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# ...

# %%
merged.groupby("committee_name_x").amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#                                     committee_name_x      amount
# 1  NEWSOM BALLOT MEASURE COMMITTEE; SAFETY FOR AL...  2829869.10
# 0  COALITION FOR CIVIL LIBERTIES - NO ON 63, A PR...   430845.42
# 2  STOP PROP 63, A GRASSROOTS, COMMON-SENSE EFFOR...   178112.56
# 3  VETO GUNMAGEDDON, CITIZENS WHO ARE OPPOSED TO ...    52309.60

# %%
# Out:
#      contributor_firstname contributor_lastname committee_position    amount
# 4153                  SEAN               PARKER            SUPPORT  400000.0
# 3427              NICHOLAS             PRITZKER            SUPPORT  250000.0
# 1543             GEORGE M.               MARCUS            SUPPORT  250000.0
# 4385        SUSIE TOMPKINS                BUELL            SUPPORT  210000.0
# 1092                 DIANE               WILSEY            SUPPORT  110000.0
# 793                 DAGMAR                DOLBY            SUPPORT  100000.0
# 72               ALEXANDER                SOROS            SUPPORT  100000.0
# 1299             ELIZABETH               SIMONS            SUPPORT  100000.0
# 1623                  GREG                WENDT            SUPPORT   50000.0
# 2917               MARC R.              BENIOFF            SUPPORT   50000.0
# 1393                  EVAN             WILLIAMS            SUPPORT   50000.0
# ...

# %%
merged.groupby(["contributor_firstname","contributor_lastname","committee_position"]).amount.sum().reset_index().sort_values("amount", ascending=False).head(15)
# Out:
#      contributor_firstname contributor_lastname committee_position    amount
# 4153                  SEAN               PARKER            SUPPORT  400000.0
# 3427              NICHOLAS             PRITZKER            SUPPORT  250000.0
# 1543             GEORGE M.               MARCUS            SUPPORT  250000.0
# 4385        SUSIE TOMPKINS                BUELL            SUPPORT  210000.0
# 1092                 DIANE               WILSEY            SUPPORT  110000.0
# 793                 DAGMAR                DOLBY            SUPPORT  100000.0
# 72               ALEXANDER                SOROS            SUPPORT  100000.0
# 1299             ELIZABETH               SIMONS            SUPPORT  100000.0
# 1623                  GREG                WENDT            SUPPORT   50000.0
# 2917               MARC R.              BENIOFF            SUPPORT   50000.0
# 1393                  EVAN             WILLIAMS            SUPPORT   50000.0
# ...
